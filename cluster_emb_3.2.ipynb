# %%
import pandas as pd
from sentence_transformers import SentenceTransformer

# Load your dataset (Make sure the Excel file is in the same directory or provide full path)
df = pd.read_excel('nadil_dataset_final.xlsx')

# View the first few rows to ensure data is loaded correctly
print(df.head())
# Out:
#         Date               Discription  Payments  Receipts   Balance
# 0        NaT                       NaN       NaN       NaN       NaN
# 1 2024-02-02           Initial Balance       NaN       NaN  12319.54
# 2 2024-02-02  0004199071001696 ATM WDR    1030.0       NaN  11289.54
# 3 2024-02-03       0710620915 BILL PYT     250.0       NaN  11039.54
# 4 2024-02-03          0443073 Fund Trf    6030.0       NaN   5009.54

# %%
# Load pre-trained SentenceTransformer model
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

# Generate embeddings for the 'Particulars' column
embeddings = model.encode(df['Discription'].tolist(), show_progress_bar=True)

# Output total embeddings and a sample embedding to verify
print(f"Total embeddings generated: {len(embeddings)}")
print(f"Sample embedding: {embeddings[0]}")
# Out:
# Batches:   0%|          | 0/14 [00:00<?, ?it/s]
# Total embeddings generated: 443
# Sample embedding: [-4.60676998e-01  5.25866568e-01 -2.41259933e-02 -4.13401932e-01
#  -2.75495768e-01 -4.99183804e-01  3.25387985e-01  2.76551574e-01
#   4.22429055e-01  4.85774279e-01  4.52098340e-01 -3.62290174e-01
#   2.87673265e-01  1.34070694e-01 -2.08634928e-01 -2.68298626e-01
#  -4.22179818e-01  2.64252394e-01  1.46887943e-01  2.36614004e-01
#   1.32615402e-01 -7.07727149e-02  5.12070954e-01 -4.68115568e-01
#   4.39195037e-01  4.16274428e-01  4.52370882e-01  1.78833939e-02
#   4.04462427e-01 -7.66960561e-01 -1.78880453e-01  2.68172652e-01
#  -3.34261090e-01  1.80803418e-01 -3.99300575e-01  7.62040675e-01
#  -3.32320064e-01 -2.43698835e-01  2.11875048e-02  2.69779056e-01
#  -5.52161522e-02  2.39256859e-01  7.27366865e-01 -1.61491290e-01
#   2.07896039e-01  4.33389336e-01  4.05823499e-01 -7.50954673e-02
#   3.83172423e-01 -6.77770451e-02 -5.60731530e-01 -7.59779289e-02
#   3.66573721e-01  1.42221704e-01  5.04500985e-01 -6.88692704e-02
#   4.50987577e-01 -3.21172386e-01 -8.78441036e-02 -3.05787921e-01
#  -1.16820835e-01  1.45094976e-01 -4.55637604e-01 -6.88069239e-02
#   7.70012558e-01 -3.86150271e-01  2.06925035e-01 -7.24504948e-01
#  -5.42909145e-01 -9.33857024e-01 -2.01549884e-02  2.63258815e-02
#  -4.78470474e-01  3.46914023e-01 -5.12843311e-01 -3.48954648e-01
#   1.77405640e-01  1.99053720e-01 -3.78466755e-01 -4.79294628e-01
#  -6.45966470e-01  4.55366045e-01  2.11137924e-02 -4.15347695e-01
#   5.77594824e-02  3.46115321e-01  4.18159813e-02 -2.11012542e-01
#   2.87196159e-01  4.88357216e-01  2.38791421e-01  8.38563919e-01
#  -1.86404422e-01 -3.98834318e-01  1.15052164e-01 -8.36170197e-01
# Check reduced embeddings shape
print(f"Reduced embeddings shape: {reduced_embeddings.shape}")
# Out:
# Reduced embeddings shape: (443, 50)

# %%
from sklearn.cluster import DBSCAN
import time

# Set DBSCAN parameters
eps = 0.5  # Maximum distance between two samples for them to be considered as in the same neighborhood
min_samples = 5  # The number of samples in a neighborhood for a point to be considered a core point

# Track the time taken for clustering
start_time = time.time()

# Apply DBSCAN clustering
dbscan = DBSCAN(eps=eps, min_samples=min_samples)
labels = dbscan.fit_predict(reduced_embeddings)

# Track time taken for clustering
end_time = time.time()
print(f"Clustering took {end_time - start_time} seconds")

# Add the cluster labels to the original dataframe
df['Cluster'] = labels

# Print the number of clusters (including noise, labeled as -1)
num_clusters = len(set(labels)) - (1 if -1 in labels else 0)
print(f"Number of clusters found: {num_clusters}")
# Out:
# Clustering took 0.5504100322723389 seconds
# Number of clusters found: 13

# %%
# Print transactions in each cluster
for cluster_num in range(n_clusters):
    print(f"\n--- Cluster {cluster_num} ---")
    cluster_transactions = df[df['Cluster'] == cluster_num]
    print(cluster_transactions[['Date', 'Discription', 'Payments', 'Receipts', 'Balance']])
    print("\n")
# Out:
# --- Cluster 0 ---
#     Date Discription  Payments  Receipts  Balance
# 0    NaT         NaN       NaN       NaN      NaN
# 64   NaT         NaN       NaN       NaN      NaN
# 274  NaT         NaN       NaN       NaN      NaN
# 306  NaT         NaN       NaN       NaN      NaN
# 337  NaT         NaN       NaN       NaN      NaN
# 368  NaT         NaN       NaN       NaN      NaN
# 399  NaT         NaN       NaN       NaN      NaN
# 430  NaT         NaN       NaN       NaN      NaN
#
#
#
# --- Cluster 1 ---
#           Date               Discription  Payments  Receipts   Balance
# 2   2024-02-02  0004199071001696 ATM WDR    1030.0       NaN  11289.54
# 6   2024-02-05  0004199071001696 ATM WDR    1030.0       NaN   3003.54
# 7   2024-02-06  0004199071001696 ATM WDR    1530.0       NaN   1473.54
# 8   2024-02-07  0004199071001696 ATM WDR     430.0       NaN   1043.54
# 11  2024-02-09  0004199071001696 ATM WDR    2530.0       NaN   3470.54
# ..         ...                       ...       ...       ...       ...
# 400 2024-12-18  0004199071001696 ATM WDR    3530.0       NaN   1010.00
# 426 2025-01-17  0004199071001696 ATM WDR    3030.0       NaN   2528.22
# 434 2025-01-24  0004199071001696 ATM WDR    2030.0       NaN   9067.22
# 438 2025-01-28  0004199071001696 ATM WDR    2030.0       NaN   3807.22
# 440 2025-01-31  0004199071001696 ATM WDR    2730.0       NaN   1037.22
#
# [94 rows x 5 columns]
#
#
#
# --- Cluster 2 ---
#           Date          Discription  Payments  Receipts   Balance
# 3   2024-02-03  0710620915 BILL PYT    250.00       NaN  11039.54
# 9   2024-02-08  0710620915 BILL PYT     43.00       NaN   1000.54
# 16  2024-02-14  0710620915 BILL PYT     50.00       NaN   2855.54
# 26  2024-02-19  0710620915 BILL PYT    250.00       NaN   9605.54
# 29  2024-02-20  0710620915 BILL PYT     50.00       NaN   4495.54
# 10  2024-02-09   0256RB01 DEP(NOV)       NaN    5000.0   6000.54
# 20  2024-02-15   0256RB01 DEP(NOV)       NaN    5000.0   6920.54
# 25  2024-02-18   0256RB01 DEP(NOV)       NaN    5000.0   9855.54
# 35  2024-02-24   0256RB01 DEP(NOV)       NaN    5000.0   2405.54
# 47  2024-03-01   0256RB01 DEP(NOV)       NaN    5000.0  16517.10
# 54  2024-03-05   0256RB01 DEP(NOV)       NaN    5000.0   6018.10
# 58  2024-03-09   0256RB01 DEP(NOV)       NaN    5000.0   6028.10
# 125 2023-05-02  0256RB01 DEP (NOV)       NaN    6000.0  57817.38
# 132 2023-05-21  0256RB01 DEP (NOV)       NaN    5000.0  60967.38
# 193 2023-08-13   0256RB01 DEP(NOV)       NaN    4000.0  22223.23
# 213 2023-08-27   0256RB01 DEP(NOV)       NaN    3000.0  14793.23
# 222 2023-09-02  0256RB01 DEP (NOV)       NaN   11000.0  12297.97
# 246 2023-09-24  0256RB01 DEP (NOV)       NaN    3000.0   7310.47
# 254 2023-10-02  0256RB01 DEP (NOV)       NaN    6000.0  12004.43
# 289 2024-09-10  0256RB01 DEP (NOV)       NaN    5000.0   6027.54
# 295 2024-09-17  0256RB01 DEP (NOV)       NaN    4000.0   5037.54
# 304 2024-09-24  0256RB01 DEP (NOV)       NaN    3000.0   4086.54
# 345 2024-10-28  0256RB01 DEP (NOV)       NaN    4000.0   5004.40
# 351 2024-11-03  0256RB01 DEP (NOV)       NaN    2000.0   3002.38
# 352 2024-11-06  0256RB01 DEP (NOV)       NaN   10000.0  13002.38
# 358 2024-11-08  0256RB01 DEP (NOV)       NaN    5000.0   6067.38
# 362 2024-11-11  0256RB01 DEP (NOV)       NaN    5000.0   6000.38
# 371 2024-11-22  0256RB01 DEP (NOV)       NaN    5000.0   6270.38
# 374 2024-11-27  0256RB01 DEP (NOV)       NaN    5000.0   6190.38
# 381 2024-12-02  0256RB01 DEP (NOV)       NaN   15000.0  15995.31
# 387 2024-12-08  0256RB01 DEP (NOV)       NaN    5000.0   7770.31
# 393 2024-12-15  0256RB01 DEP (NOV)       NaN    5000.0   6000.00
# 398 2024-12-18  0256RB01 DEP (NOV)       NaN    3500.0   4540.00
# 401 2024-12-26  0256RB01 DEP (NOV)       NaN    1500.0   2510.00
# 403 2024-12-26  0256RB01 DEP (NOV)       NaN       NaN   2960.00
# 421 2025-01-08  0256RB01 DEP (NOV)       NaN    1500.0   2546.22
# 424 2025-01-13  0256RB01 DEP (NOV)       NaN    5000.0   6000.22
#
#
#
# --- Cluster 4 ---
#           Date         Discription  Payments  Receipts   Balance
# 13  2024-02-13   0057RB01 DEP(NOV)       NaN    5000.0   6465.54
# 201 2023-08-20   0057RB01 DEP(NOV)       NaN    5000.0  17073.23
# 231 2023-09-09  0057RB01 DEP (NOV)       NaN    5000.0  11870.47
# 367 2024-11-18  0057RB01 DEP (NOV)       NaN    2000.0   3000.38
# 411 2025-01-02  0057RB01 DEP (NOV)       NaN    7500.0   8508.22
#
#
#
# --- Cluster 5 ---
#           Date                Discription  Payments  Receipts   Balance
# 17  2024-02-14  FT FRM SEY -HELA EFT OTHE       NaN    1050.0   3905.54
# 115 2023-03-10  FT FRM SEY -HELA EFT OTHE       NaN    6000.0  60883.99
# 232 2023-09-11  FT FRM SEY -HELA EFT OTHE       NaN    1000.0  12870.47
# 233 2023-09-11  FT FRM SEY -HELA EFT OTHE       NaN    1730.0  14600.47
# 238 2023-09-15  FT FRM SEY -HELA EFT OTHE       NaN     400.0  10010.47
# 264 2023-10-09  FT FRM SEY -HELA EFT OTHE       NaN    7630.0  32250.35
# 265 2023-10-09  FT FRM SEY -HELA EFT OTHE       NaN    1550.0  33800.35
#
#
#
# --- Cluster 6 ---
#           Date                 Discription  Payments  Receipts   Balance
# 39  2024-02-28   RIB/RMB SE.CH 20 IBMB Chg      40.0       NaN   4125.54
# 70  2022-11-15   RIB/RMB SE.CH 20 IBMB Chg      25.0       NaN   9399.64
# 117 2023-03-30  RIB/RMB SE. CH 20 IBMB Chg      40.0       NaN  55813.99
# 122 2023-04-29  RIB/RMB SE. CH 20 IBMB Chg      40.0       NaN  51673.86
# 135 2023-05-28  RIB/RMB SE. CH 20 IBMB Chg      40.0       NaN  57367.38
# 148 2023-06-30  RIB/RMB SE. CH 20 IBMB Chg      40.0       NaN  57043.21
# 169 2023-07-30   RIB/RMB SE.CH 20 IBMB Chg      40.0       NaN  51010.39
# 217 2023-08-31  RIB/RMB SE. CH 20 IBMB chg      40.0       NaN  15293.23
# 248 2023-09-30   RIB/RMB SE.CH 20 IBMB chg      40.0       NaN   6270.47
# 277 2024-08-31   RIB/RMB SE.CH 20 IBMB Chg      40.0       NaN   2604.57
# 316 2024-10-04   RIB/RMB SE.CH 20 IBMB Chg      40.0       NaN   5984.40
# 344 2024-10-28   RIB/RMB SE.CH 20 IBMB Chg      40.0       NaN   1004.40
# 378 2024-11-30   RIB/RMB SE.CH 20 IBMB Chg      40.0       NaN    990.38
# 406 2024-12-28   RIB/RMB SE.CH 20 IBMB chg      40.0       NaN    960.00
# 439 2025-01-30   RIB/RMB SE.CH 20 IBMB Chg      40.0       NaN   3767.22
#
#
#
# --- Cluster 7 ---
#           Date                Discription  Payments  Receipts  Balance
# 40  2024-02-28  SmsServiceCharge IBMB Chg      50.0       NaN  4085.54
# 297 2024-09-17  SmsServiceCharge IBMB Chg      50.0       NaN  4040.54
# 343 2024-10-24  SmsServiceCharge IBMB Chg      50.0       NaN  1044.40
# 373 2024-11-24  SmsServiceCharge IBMB Chg      50.0       NaN  1190.38
# 402 2024-12-26  SmsServiceCharge IBMB chg      50.0     500.0  2460.00
# 437 2025-01-27  Smsservicecharge IBMB Chg      50.0       NaN  5837.22
#
#
#
# --- Cluster 8 ---
#           Date               Discription  Payments  Receipts   Balance
# 42  2024-02-29                      INT        NaN     12.16   2017.70
# 67  2022-10-31                       INT       NaN      4.64  18484.64
# 73  2022-11-30                       INT       NaN  20240.00  31777.14
# 86  2022-12-31                       INT       NaN    114.05  68565.20
# 93  2023-01-31                       INT       NaN    185.71  73200.91
# 104 2023-02-28                       INT       NaN    186.69  75148.32
# 119 2023-03-31                       INT       NaN    176.17  57752.66
# 123 2023-04-30                       INT       NaN    151.07  51824.93
# 136 2023-05-31                       INT       NaN    164.03  57531.41
# 149 2023-06-30                       INT       NaN    165.45  57208.66
# 171 2023-07-31                       INT       NaN    118.77  50929.16
# 219 2023-08-31                       INT       NaN     68.14  12331.37
# 251 2023-09-30                       INT       NaN     25.22   6265.69
# 278 2024-08-31                       INT       NaN     11.54   2616.11
# 311 2024-09-30                       INT       NaN      8.27   4084.81
# 348 2024-10-31                       INT       NaN     10.50   3332.90
# 379 2024-11-30                       INT       NaN      5.18    995.56
# 409 2024-12-31                       INT       NaN      8.65   1008.65
# 441 2025-01-31                       INT       NaN     11.26   1048.48
#
#
#
# --- Cluster 9 ---
#           Date                 Discription  Payments  Receipts   Balance
# 43  2024-02-29                     WH TAX       0.60       NaN   2017.10
# 94  2023-01-31                      WH TAX      9.28       NaN  73191.63
# 105 2023-02-28                      WH TAX      9.33       NaN  75138.99
# 120 2023-03-31                      WH TAX      8.80       NaN  57743.86
# 124 2023-04-30                      WH TAX      7.55       NaN  51817.38
# 137 2023-05-31                      WH TAX      8.20       NaN  57523.21
# 150 2023-06-30                      WH TAX      8.27       NaN  57200.39
# 172 2023-07-31                      WH TAX      5.93       NaN  50923.23
# 220 2023-08-31                      WH TAX      3.40       NaN  12327.97
# 252 2023-09-30                      WH TAX      1.26       NaN   6264.43
# 279 2024-08-31                      WH TAX      0.57       NaN   2615.54
# 349 2024-10-31                      WH TAX      0.52       NaN   3332.38
# 380 2024-11-30                      WH TAX      0.25       NaN    995.31
# 410 2024-12-31                      WH TAX      0.43       NaN   1008.22
# 442 2025-01-31                      WH TAX      0.56       NaN   1047.92
#
#
#
# --- Cluster 10 ---
#           Date              Discription  Payments  Receipts   Balance
# 66  2022-10-31                      TRF       NaN  17480.00  18480.00
# 71  2022-11-16                      TRF       NaN   2587.50  11987.14
# 74  2022-11-30                      TRF       NaN     36.51  31813.65
# 75  2022-12-09                      TRF       NaN   2981.25  34794.90
# 81  2022-12-29                      TRF       NaN   1500.00  49734.90
# 82  2022-12-29                      TRF       NaN   2156.25  51891.15
# 85  2022-12-30                      TRF       NaN  16560.00  68451.15
# 90  2023-01-31                      TRF       NaN  15640.00  73015.20
# 101 2023-02-28                      TRF       NaN  15640.00  75641.63
# 102 2023-02-28                      TRF       NaN   2325.00  77966.63
# 118 2023-03-31                      TRF       NaN   1762.50  57576.49
# 258 2023-10-04                      TRF       NaN  22472.92  42342.35
#
#
#
# --- Cluster 11 ---
#           Date          Discription  Payments  Receipts   Balance
# 170 2023-07-30  0711305386 BILL PYT     200.0       NaN  50810.39
# 176 2023-08-04  0711305386 BILL PYT     200.0       NaN  34193.23
# 181 2023-08-06  0711305386 BILL PYT     300.0       NaN  43833.23
# 303 2024-09-24  0711305386 BILL PYT     200.0       NaN   1086.54
# 395 2024-12-15  0711305386 BILL PYT     200.0       NaN   3770.00
#
#
#
# --- Cluster 12 ---
#           Date          Discription  Payments  Receipts   Balance
# 182 2023-08-06  0760232652 BILL PYT     100.0       NaN  43733.23
# 187 2023-08-10  0760232652 BILL PYT     150.0       NaN  29393.23
# 225 2023-09-04  0760232652 BILL PYT     100.0       NaN  18197.97
# 236 2023-09-14  0760232652 BILL PYT     200.0       NaN  11140.47
# 242 2023-09-20  0760232652 BILL PYT      80.0       NaN   5090.47
# 256 2023-10-03  0760232652 BILL PYT     105.0       NaN  21899.43
# 260 2023-10-06  0760232652 BILL PYT      60.0       NaN  28680.35
# 383 2024-12-02  0760232652 BILL PYT     197.0       NaN  12768.31
#
#
#
# --- Cluster 13 ---
# Empty DataFrame
# Columns: [Date, Discription, Payments, Receipts, Balance]
# Index: []
#
#
#
# --- Cluster 14 ---
# Empty DataFrame
# Columns: [Date, Discription, Payments, Receipts, Balance]
# Index: []
#
#
#
# --- Cluster 15 ---
# Empty DataFrame
# Columns: [Date, Discription, Payments, Receipts, Balance]
# Index: []
#
#
#
# --- Cluster 16 ---
# Empty DataFrame
# Columns: [Date, Discription, Payments, Receipts, Balance]
# Index: []
#
#
#
# --- Cluster 17 ---
# Empty DataFrame
# Columns: [Date, Discription, Payments, Receipts, Balance]
# Index: []
#
#
#
# --- Cluster 18 ---
# Empty DataFrame
# Columns: [Date, Discription, Payments, Receipts, Balance]
# Index: []
#
#
#
# --- Cluster 19 ---
# Empty DataFrame
# Columns: [Date, Discription, Payments, Receipts, Balance]
# Index: []
#
#
#
# --- Cluster 20 ---
# Empty DataFrame
# Columns: [Date, Discription, Payments, Receipts, Balance]
# Index: []
#
#
#
# --- Cluster 21 ---
# Empty DataFrame
# Columns: [Date, Discription, Payments, Receipts, Balance]
# Index: []
#
#
#
# --- Cluster 22 ---
# Empty DataFrame
# Columns: [Date, Discription, Payments, Receipts, Balance]
# Index: []
#
#
#
# --- Cluster 23 ---
# Empty DataFrame
# Columns: [Date, Discription, Payments, Receipts, Balance]
# Index: []
#
#
#
# --- Cluster 24 ---
# Empty DataFrame
# Columns: [Date, Discription, Payments, Receipts, Balance]
# Index: []
#
#
#
# --- Cluster 25 ---
# Empty DataFrame
# Columns: [Date, Discription, Payments, Receipts, Balance]
# Index: []
#
#
#
# --- Cluster 26 ---
# Empty DataFrame
# Columns: [Date, Discription, Payments, Receipts, Balance]
# Index: []
#
#
#
# --- Cluster 27 ---
# Empty DataFrame
# Columns: [Date, Discription, Payments, Receipts, Balance]
# Index: []
#
#
#
# --- Cluster 28 ---
# Empty DataFrame
# Columns: [Date, Discription, Payments, Receipts, Balance]
# Index: []
#
#
#
# --- Cluster 29 ---
# Empty DataFrame
# Columns: [Date, Discription, Payments, Receipts, Balance]
# Index: []
